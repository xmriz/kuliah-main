# %% [markdown]
# # **Impor Data**

# %%
# Impor Data
import pandas as pd
import matplotlib.pyplot as plt

dffin = pd.read_csv('financial.csv')
dffin
# Out:
#               Segment                   Country    Product DiscountBand  \
# 0          Government                    Canada  Carretera         None
# 1          Government                   Germany  Carretera         None
# 2           Midmarket                    France  Carretera         None
# 3           Midmarket                   Germany  Carretera         None
# 4           Midmarket                    Mexico  Carretera         None
# ..                ...                       ...        ...          ...
# 695    Small Business                    France   Amarilla         High
# 696    Small Business                    Mexico   Amarilla         High
# 697        Government                    Mexico    Montana         High
# 698        Government                    Canada      Paseo         High
# 699  Channel Partners  United States of America        VTT         High
#
#      UnitsSold  ManufacturingPrice  SalePrice  GrossSales  Discounts  \
# ...

# %% [markdown]
# # **Data Understanding**

# %%
dffin.info()

# 1. 700 baris
# 2. 16 kolom
# 3.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Segment             700 non-null    object
#  1   Country             700 non-null    object
#  2   Product             700 non-null    object
#  3   DiscountBand        700 non-null    object
#  4   UnitsSold           700 non-null    float64
#  5   ManufacturingPrice  700 non-null    int64
#  6   SalePrice           700 non-null    int64
#  7   GrossSales          700 non-null    float64
#  8   Discounts           647 non-null    float64
#  9   Sales               700 non-null    float64
#  10  COGS                700 non-null    float64
#  11  Profit              695 non-null    float64
#  12  Date                700 non-null    object
#  13  MonthNumber         700 non-null    int64
#  14  MonthName           700 non-null    object
# ...

# %% [markdown]
# # **Statistics**

# %% [markdown]
# MonthNumber, Year, SalePrice, ManufacturingPrice

# %%
print (dffin['Year'].describe())
print(20*'-')
print (dffin['MonthNumber'].describe())
print(20*'-')
print (dffin['SalePrice'].describe())
print(20*'-')
print (dffin['SalePrice'].describe())
print(20*'-')
print (dffin['ManufacturingPrice'].describe())
# Out:
# count     700.000000
# mean     2013.750000
# std         0.433322
# min      2013.000000
# 25%      2013.750000
# 50%      2014.000000
# 75%      2014.000000
# max      2014.000000
# Name: Year, dtype: float64
# --------------------
# count    700.000000
# mean       7.900000
# std        3.377321
# min        1.000000
# 25%        5.750000
# 50%        9.000000
# 75%       10.250000
# max       12.000000
# Name: MonthNumber, dtype: float64
# --------------------
# count    700.000000
# mean     118.428571
# std      136.775515
# min        7.000000
# 25%       12.000000
# 50%       20.000000
# 75%      300.000000
# max      350.000000
# Name: SalePrice, dtype: float64
# --------------------
# count    700.000000
# mean     118.428571
# std      136.775515
# min        7.000000
# 25%       12.000000
# 50%       20.000000
# 75%      300.000000
# max      350.000000
# Name: SalePrice, dtype: float64
# --------------------
# count    700.000000
# mean      96.477143
# ...

# %% [markdown]
# # **Data Exploration**

# %%
dffin.loc[(dffin['MonthName'] == 'December') & (dffin['Year'] == 2014)]
# Out:
#               Segment                   Country    Product DiscountBand  \
# 5          Government                   Germany  Carretera         None
# 15          Midmarket  United States of America    Montana         None
# 29         Government                    Canada      Paseo         None
# 30         Government                   Germany      Paseo         None
# 44         Government                    Canada        VTT         None
# ..                ...                       ...        ...          ...
# 637         Midmarket                    Canada    Montana         High
# 680  Channel Partners  United States of America      Paseo         High
# 681        Government                    France      Paseo         High
# 687  Channel Partners  United States of America       Velo         High
# 694        Government                    France        VTT         High
#
#      UnitsSold  ManufacturingPrice  SalePrice  GrossSales  Discounts  \
# ...

# %%
dffin.loc[dffin['UnitsSold'] > 1000]
# Out:
#               Segment                   Country    Product DiscountBand  \
# 0          Government                    Canada  Carretera         None
# 1          Government                   Germany  Carretera         None
# 2           Midmarket                    France  Carretera         None
# 4           Midmarket                    Mexico  Carretera         None
# 5          Government                   Germany  Carretera         None
# ..                ...                       ...        ...          ...
# 691         Midmarket                   Germany        VTT         High
# 692        Enterprise                    Canada        VTT         High
# 695    Small Business                    France   Amarilla         High
# 697        Government                    Mexico    Montana         High
# 699  Channel Partners  United States of America        VTT         High
#
#      UnitsSold  ManufacturingPrice  SalePrice  GrossSales  Discounts  \
# ...

# %%
dffin.sort_values(['Sales'], ascending=1)[:10]
# Out:
#         Segment                   Country    Product DiscountBand  UnitsSold  \
# 359  Government                    Canada      Paseo       Medium      257.0
# 615  Government                   Germany  Carretera         High      280.0
# 622  Government                   Germany        VTT         High      280.0
# 278  Government  United States of America  Carretera       Medium      263.0
# 616  Government                    France    Montana         High      293.0
# 88   Government                   Germany        VTT          Low      263.0
# 449  Government                   Germany        VTT       Medium      360.0
# 446  Government                   Germany      Paseo       Medium      360.0
# 635  Government                    Canada    Montana         High      388.0
# 535  Government  United States of America      Paseo         High      380.0
#
#      ManufacturingPrice  SalePrice  GrossSales  Discounts    Sales    COGS  \
# ...

# %%
dffin.groupby(['Country'])['Profit'].sum()
# Out:
# Country
# Canada                      3858206.39
# France                      4032488.29
# Germany                     3961381.32
# Mexico                      3198923.11
# United States of America    3397345.68
# Name: Profit, dtype: float64

# %%
T2013 = dffin.loc[dffin['Year'] == 2013]
T2013['Segment'].value_counts()
# Out:
# Government          75
# Enterprise          25
# Midmarket           25
# Small Business      25
# Channel Partners    25
# Name: Segment, dtype: int64

# %%
dffin.sort_values(['Year', 'MonthNumber'], ascending = True)
# Out:
#               Segment                   Country    Product DiscountBand  \
# 22          Midmarket                    France      Paseo         None
# 23     Small Business                    Mexico      Paseo         None
# 42         Government                    France        VTT         None
# 62         Enterprise  United States of America  Carretera          Low
# 72     Small Business  United States of America    Montana          Low
# ..                ...                       ...        ...          ...
# 637         Midmarket                    Canada    Montana         High
# 680  Channel Partners  United States of America      Paseo         High
# 681        Government                    France      Paseo         High
# 687  Channel Partners  United States of America       Velo         High
# 694        Government                    France        VTT         High
#
#      UnitsSold  ManufacturingPrice  SalePrice  GrossSales  Discounts  \
# ...

# %%
dffin['Product'].sort_values()
# Out:
# 664    Amarilla
# 665    Amarilla
# 352    Amarilla
# 137    Amarilla
# 401    Amarilla
#          ...
# 603        Velo
# 602        Velo
# 601        Velo
# 260        Velo
# 605        Velo
# Name: Product, Length: 700, dtype: object

# %%
df2 = dffin[dffin['Year'] == 2014].groupby(['Product'])['Profit'].sum()
df2.plot(kind= 'bar')
df2
# Out:
# Product
# Amarilla     2252007.04
# Carretera    2079171.03
# Montana      1701026.84
# Paseo        3936922.37
# VTT          2318667.79
# Velo         1837410.21
# Name: Profit, dtype: float64
