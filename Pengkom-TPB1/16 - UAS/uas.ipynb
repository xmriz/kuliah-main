# %%
import pandas as pd
import matplotlib as plt

# %%
df = pd.read_excel('WorldCups.xlsx')

# %%
df
# Out:
#     Year       Country Organization      Winner      Runners-Up  GoalsScored  \
# 0   1930       Uruguay     CONMEBOL     Uruguay       Argentina          NaN
# 1   1934         Italy         UEFA       Italy  Czechoslovakia         70.0
# 2   1938        France         UEFA       Italy         Hungary         84.0
# 3   1950        Brazil     CONMEBOL     Uruguay          Brazil         88.0
# 4   1954   Switzerland         UEFA  Germany FR         Hungary        140.0
# 5   1958        Sweden         UEFA      Brazil          Sweden        126.0
# 6   1962         Chile     CONMEBOL      Brazil  Czechoslovakia         89.0
# 7   1966       England         UEFA     England      Germany FR         89.0
# 8   1970        Mexico     CONCACAF      Brazil           Italy         95.0
# 9   1970        Mexico     CONCACAF      Brazil           Italy          NaN
# 10  1974       Germany         UEFA  Germany FR     Netherlands         97.0
# ...

# %%
df['GoalsScored'] = df['GoalsScored'].fillna(0)
df['QualifiedTeams'] = df['QualifiedTeams'].fillna(0)
df['MatchesPlayed'] = df['MatchesPlayed'].fillna(0)
df['Attendance'] = df['Attendance'].fillna(0)

df['GoalsScored'] = df['GoalsScored'].abs()
df['QualifiedTeams'] = df['QualifiedTeams'].abs()
df['MatchesPlayed'] = df['MatchesPlayed'].abs()
df['Attendance'] = df['Attendance'].abs()

# %%
df
# Out:
#     Year       Country Organization      Winner      Runners-Up  GoalsScored  \
# 0   1930       Uruguay     CONMEBOL     Uruguay       Argentina          0.0
# 1   1934         Italy         UEFA       Italy  Czechoslovakia         70.0
# 2   1938        France         UEFA       Italy         Hungary         84.0
# 3   1950        Brazil     CONMEBOL     Uruguay          Brazil         88.0
# 4   1954   Switzerland         UEFA  Germany FR         Hungary        140.0
# 5   1958        Sweden         UEFA      Brazil          Sweden        126.0
# 6   1962         Chile     CONMEBOL      Brazil  Czechoslovakia         89.0
# 7   1966       England         UEFA     England      Germany FR         89.0
# 8   1970        Mexico     CONCACAF      Brazil           Italy         95.0
# 9   1970        Mexico     CONCACAF      Brazil           Italy          0.0
# 10  1974       Germany         UEFA  Germany FR     Netherlands         97.0
# ...

# %%
# Rata-rata banyaknya penonton pertandingan.
df['Attendance'].mean()
# Out:
# 1675777.1818181819

# %%
# Deviasi standar banyaknya gol yang tercipta.
df['GoalsScored'].std()
# Out:
# 51.823397246461006

# %%
# Berapa kali Mexico menjadi tuan rumah.
len(df.loc[df['Country'] == 'Mexico'])
# Out:
# 3

# %%
import pandas as pd
import matplotlib as plt

df = pd.read_excel('WorldCups.xlsx')

df['GoalsScored'] = df['GoalsScored'].fillna(0)
df['QualifiedTeams'] = df['QualifiedTeams'].fillna(0)
df['MatchesPlayed'] = df['MatchesPlayed'].fillna(0)
df['Attendance'] = df['Attendance'].fillna(0)

df['GoalsScored'] = df['GoalsScored'].abs()
df['QualifiedTeams'] = df['QualifiedTeams'].abs()
df['MatchesPlayed'] = df['MatchesPlayed'].abs()
df['Attendance'] = df['Attendance'].abs()

pesertaLebihdari20_df = df.loc[df['QualifiedTeams'] > 20]
pesertaLebihdari20_df.plot(kind='line', x='Year', y='Attendance', title = f'pergerakan banyaknya penonton dari tahun ke tahun untuk data saat banyaknya peserta lebih dari 20 tim\n')
# Out:
# <AxesSubplot:title={'center':'pergerakan banyaknya penonton dari tahun ke tahun untuk data saat banyaknya peserta lebih dari 20 tim\n'}, xlabel='Year'>

# %%
import pandas as pd
import matplotlib as plt

df = pd.read_excel('WorldCups.xlsx')

df['GoalsScored'] = df['GoalsScored'].fillna(0)
df['QualifiedTeams'] = df['QualifiedTeams'].fillna(0)
df['MatchesPlayed'] = df['MatchesPlayed'].fillna(0)
df['Attendance'] = df['Attendance'].fillna(0)

df['GoalsScored'] = df['GoalsScored'].abs()
df['QualifiedTeams'] = df['QualifiedTeams'].abs()
df['MatchesPlayed'] = df['MatchesPlayed'].abs()
df['Attendance'] = df['Attendance'].abs()

df = pd.read_excel('WorldCups.xlsx')

df['Winner'].value_counts().plot(kind='pie', legend=True, figsize=(10,10), autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Winner'>

# %%
import pandas as pd
import matplotlib as plt

df = pd.read_excel('WorldCups.xlsx')

df['GoalsScored'] = df['GoalsScored'].fillna(0)
df['QualifiedTeams'] = df['QualifiedTeams'].fillna(0)
df['MatchesPlayed'] = df['MatchesPlayed'].fillna(0)
df['Attendance'] = df['Attendance'].fillna(0)

df['GoalsScored'] = df['GoalsScored'].abs()
df['QualifiedTeams'] = df['QualifiedTeams'].abs()
df['MatchesPlayed'] = df['MatchesPlayed'].abs()
df['Attendance'] = df['Attendance'].abs()

df = pd.read_excel('WorldCups.xlsx')

df['Organization'].value_counts().plot(kind='pie', legend=True, figsize=(10,10), autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Organization'>

# %%
import pandas as pd
import matplotlib as plt

df = pd.read_excel('WorldCups.xlsx')

df['GoalsScored'] = df['GoalsScored'].fillna(0)
df['QualifiedTeams'] = df['QualifiedTeams'].fillna(0)
df['MatchesPlayed'] = df['MatchesPlayed'].fillna(0)
df['Attendance'] = df['Attendance'].fillna(0)

df['GoalsScored'] = df['GoalsScored'].abs()
df['QualifiedTeams'] = df['QualifiedTeams'].abs()
df['MatchesPlayed'] = df['MatchesPlayed'].abs()
df['Attendance'] = df['Attendance'].abs()

df['QualifiedTeams'].corr(df['GoalsScored'])
# Out:
# 0.9395318804399021
