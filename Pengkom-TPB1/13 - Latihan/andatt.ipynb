# %%
import pandas as pd
import matplotlib as plt

df = pd.read_csv('crypto.csv')

# %% [markdown]
# # **PROBLEM 1**

# %%
# banyaknya data
len(df)
# Out:
# 8219

# %%
# 5 data pertama
df.head()
# Out:
#   name        date  ranknow    open    high     low   close  volume  \
# 0  BTC  2013-04-28        1  135.30  135.98  132.10  134.21     0.0
# 1  BTC  2013-04-29        1  134.44  147.49  134.00  144.54     0.0
# 2  BTC  2013-04-30        1  144.00  146.93  134.05  139.00     0.0
# 3  BTC  2013-05-01        1  139.00  139.89  107.72  116.99     0.0
# 4  BTC  2013-05-02        1  116.38  125.60   92.28  105.21     0.0
#
#          market  close_ratio  spread
# 0  1.488567e+09       0.5438    3.88
# 1  1.603769e+09       0.7813   13.49
# 2  1.542813e+09       0.3843   12.88
# 3  1.298955e+09       0.2882   32.17
# 4  1.168517e+09       0.3881   33.32

# %%
# data ke 406 sampai 410
df[406:411]
# Out:
#     name        date  ranknow    open    high     low   close      volume  \
# 406  BTC  2014-06-08        1  654.99  658.88  653.47  656.14   8614190.0
# 407  BTC  2014-06-09        1  655.64  657.70  644.39  649.16  19065400.0
# 408  BTC  2014-06-10        1  650.04  659.61  646.56  653.15  17913400.0
# 409  BTC  2014-06-11        1  653.19  657.04  632.55  633.02  25163800.0
# 410  BTC  2014-06-12        1  633.43  638.11  573.27  586.95  50818800.0
#
#            market  close_ratio  spread
# 406  8.445490e+09       0.4935    5.41
# 407  8.358149e+09       0.3584   13.31
# 408  8.412294e+09       0.5050   13.05
# 409  8.155307e+09       0.0192   24.49
# 410  7.564344e+09       0.2110   64.84

# %%
# jumlah masing-masing koin
df['name'].value_counts()
# Out:
# BTC     2042
# XRP     1944
# XMR     1653
# USDT    1369
# ETH     1211
# Name: name, dtype: int64

# %%
# nilai korelasi volume dan close ratio
df['volume'].corr(df['close_ratio'])
# Out:
# 0.06928981923659844

# %% [markdown]
# # **Problem 2**

# %%
# data untuk koin XMR
df_XMR = df.loc[df['name'] == 'XMR']
df_XMR
# Out:
#      name        date  ranknow   open   high    low  close      volume  \
# 6566  XMR  2014-05-21       11   2.47   2.65   1.23   1.60    246540.0
# 6567  XMR  2014-05-22       11   1.59   2.19   1.36   2.10    132918.0
# 6568  XMR  2014-05-23       11   2.05   3.43   2.05   2.96    266852.0
# 6569  XMR  2014-05-24       11   2.92   4.01   2.62   3.70    248028.0
# 6570  XMR  2014-05-25       11   4.04   4.04   2.80   3.14    283545.0
# ...   ...         ...      ...    ...    ...    ...    ...         ...
# 8214  XMR  2018-11-25       11  58.37  59.35  53.10  58.05  24217900.0
# 8215  XMR  2018-11-26       11  58.13  59.98  52.28  53.22  21913900.0
# 8216  XMR  2018-11-27       11  53.12  58.47  52.39  57.13  19314700.0
# 8217  XMR  2018-11-28       11  57.42  65.74  57.29  63.52  18065200.0
# 8218  XMR  2018-11-29       11  63.87  64.75  59.42  61.20  16842316.0
#
#             market  close_ratio  spread
# 6566  1.382563e+06       0.2606    1.42
# ...

# %%
# 2 maret 2015
df.loc[df['date'] == '2015-03-02']
# Out:
#       name        date  ranknow        open        high         low  \
# 673    BTC  2015-03-02        1  260.360000  276.300000  258.310000
# 2617   XRP  2015-03-02        2    0.012233    0.012235    0.011931
# 5199  USDT  2015-03-02        8    0.571249    0.607890    0.568314
# 6850   XMR  2015-03-02       11    0.425727    0.431746    0.384157
#
#            close      volume        market  close_ratio  spread
# 673   275.670000  40465700.0  3.831179e+09       0.9650   17.99
# 2617    0.012192   1284250.0  3.890323e+08       0.8586    0.00
# 5199    0.606502         3.0  1.525960e+05       0.9649    0.04
# 6850    0.428434     67915.0  2.791266e+06       0.9304    0.05

# %%
# 5 data dengan low terendah
df.sort_values('low').head()
# Out:
#      name        date  ranknow      open      high       low     close  \
# 2379  XRP  2014-07-07        2  0.002809  0.003082  0.002802  0.003082
# 2378  XRP  2014-07-06        2  0.003134  0.003169  0.002804  0.002810
# 2054  XRP  2013-08-16        2  0.003082  0.003162  0.002875  0.003134
# 2334  XRP  2014-05-23        2  0.003963  0.003976  0.003063  0.003315
# 2053  XRP  2013-08-15        2  0.003788  0.003804  0.003067  0.003092
#
#          volume      market  close_ratio  spread
# 2379   191510.0  24096300.0       1.0000     0.0
# 2378   148862.0  21969912.0       0.0164     0.0
# 2054        0.0  24497514.0       0.9024     0.0
# 2334  1174650.0  25918572.0       0.2760     0.0
# 2053        0.0  24172681.0       0.0339     0.0

# %%
# nilai high tertinggi
high_max = df['high'].max()
print('nilai high tertinggi adalah', high_max)
# Out:
# nilai high tertinggi adalah 20089.0

# %%
xmr_df = df.loc[df['name'] == 'XMR']
xmr_df.loc[xmr_df['high'] == xmr_df['high'].max()]['date']
# Out:
# 7892    2018-01-07
# Name: date, dtype: object

# %% [markdown]
# # **Problem 3**

# %%
ETH = df.loc[df['name'] == 'ETH']
ETH.groupby('date')['close'].size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10400/467424648.py in <module>
# ----> 1 ETH = df.loc[df['name'] == 'ETH']
#       2 ETH.groupby('date')['close'].size()
#
# NameError: name 'df' is not defined

# %%
df4 = df.loc[df["date"] == "2015-03-02"].groupby("name")
df4['market'].sum().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='market'>

# %%
print(df.groupby(["date", "name"])["close"].sum().unstack())
df.groupby(["date", "name"])["close"].sum().unstack().plot(kind="line", title="Line Chart Nilai Close BTC, ETH, XRP, USDT, dan XMR")
# Out:
# name            BTC     ETH      USDT    XMR       XRP
# date
# 2013-04-28   134.21     NaN       NaN    NaN       NaN
# 2013-04-29   144.54     NaN       NaN    NaN       NaN
# 2013-04-30   139.00     NaN       NaN    NaN       NaN
# 2013-05-01   116.99     NaN       NaN    NaN       NaN
# 2013-05-02   105.21     NaN       NaN    NaN       NaN
# ...             ...     ...       ...    ...       ...
# 2018-11-25  4009.97  116.45  0.980969  58.05  0.374551
# 2018-11-26  3779.13  108.33  0.977243  53.22  0.355451
# 2018-11-27  3820.72  110.01  0.984260  57.13  0.360163
# 2018-11-28  4257.42  122.44  0.998622  63.52  0.390557
# 2018-11-29  4278.85  117.54  0.997377  61.20  0.379562
#
# [2042 rows x 5 columns]
# <AxesSubplot:title={'center':'Line Chart Nilai Close BTC, ETH, XRP, USDT, dan XMR'}, xlabel='date'>
